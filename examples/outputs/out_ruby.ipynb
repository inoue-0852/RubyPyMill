# %% [markdown]
# # Sample Notebook
# Parameters below.

# %%
name = "Ruby PyMill"
n = 5

# %%
for i in range(n):
    print(f"Hello, {name}! #{i+1}")
# Out:
# Hello, Ruby PyMill! #1
# Hello, Ruby PyMill! #2
# Hello, Ruby PyMill! #3
# Hello, Ruby PyMill! #4
# Hello, Ruby PyMill! #5
